# %% [markdown]
# # House Price Prediction
# Introduction
# Dataset Statistics
# Number of House Data Enteries: 21613
# Highest Price of a Property: 7.7 Lacs
# Most Ancient Property: 1900
# Maximum Square Footage Area : 16,51,359 Sq. Ft
# Maximum Bedroom's in a House: 33
#
# ## Data Fields Explanation
# The House Price Prediction Dataset consists of 21,613 House Data Enteries. This Dataset consists of a Single CSV file, Data.csv. The columns in the table are:
#
# Id : Unique row number
# Date : The Date Price was Last Checked
# Price : The Price of the Property
# Bedrooms : Number of Bedrooms
# Bathrooms : Number of Bathrooms
# Sqft_living : Square Footage of Living Room
# Sqft_lot : Square Footage of Lot.
# Floors : Number of Floors
# Waterfront : If the House has a Waterfront
# View : If the House has a View
# Condition : Condition of the House 1 Being the Best
# Grade : Grade Assigned
# Sqft_above : Square Footage of Above
# Sqft_basement : Square Footage of Basement
# Yr_built : Year The House was built
# Yr_renovated : Year The House was built
# Zipcode : Zipcode
# Lat : Latitude
# Long : Longitude

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('kc_house_data.csv')
df=pd.DataFrame(data)
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-0e566b70f572> in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (21613, 21)

# %%
# we have data of  21613 houses
from scipy import stats
df1 = df.drop('date', 1)
z = np.abs(stats.zscore(df1))
df1 = df1[(z < 3).all(axis=1)]

# %%
df1.dropna()
df1.shape
# Out:
# (18702, 20)

# %%
df.coloums
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-520b24a44c92> in <module>
# ----> 1 df.coloums
#
# c:\users\asus\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'coloums'

# %%
df.coloums()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-c00e4de84ef8> in <module>
# ----> 1 df.coloums()
#
# c:\users\asus\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'coloums'

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df1['floorInt'] = df1['floors'].astype(int)
df1['floorInt'].head()
# Out:
# 0    1
# 2    1
# 3    1
# 4    1
# 6    2
# Name: floorInt, dtype: int32

# %%
df1.shape
# Out:
# (18702, 21)

# %%
df1.columns
# Out:
# Index(['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'floorInt'],
#       dtype='object')

# %%
df1.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
# 6  1321400060  257500.0         3       2.25         1715      6819     2.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
# 6           0     0          3  ...        1715              0      1995
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 0             0    98178  47.5112 -122.257           1340        5650
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503
# 6             0    98003  47.3097 -122.327           2238        6819
#
#    floorInt
# 0         1
# 2         1
# 3         1
# 4         1
# 6         2
#
# [5 rows x 21 columns]

# %%
sns.distplot(df1['floorInt'], kde=False, rug=True)

# %% [markdown]
# sns.distplot(df1['floors'], kde=False, rug=True)

# %%
sns.distplot(df1['yr_built'], kde=False, rug=True)

# %% [markdown]
# # Max number of houses are built between 2000-2020

# %%
sns.kdeplot(df1['yr_built'], shade=True)

# %% [markdown]
# #  bivariate analysis

# %%
sns.barplot(x='bedrooms',y='price',hue='waterfront', data =df)

# %%
# Waterfront houses have maximum 6 rooms
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
df['yr_reno']=(df['yr_renovated']>0).astype(int)
df.shape
# Out:
# (21613, 22)

# %%
sns.barplot(x='floorInt',y='price',hue='yr_reno', data =df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-2529e0ede395> in <module>
# ----> 1 sns.barplot(x='floorInt',y='price',hue='yr_reno', data =df)
#
# c:\users\asus\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# c:\users\asus\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# c:\users\asus\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'floorInt'

# %%
sns.barplot(x='floors',y='price',hue='yr_reno', data =df)

# %%
sns.barplot(x='floorInt',y='price',hue='yr_reno', data =df1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-2529e0ede395> in <module>
# ----> 1 sns.barplot(x='floorInt',y='price',hue='yr_reno', data =df)
#
# c:\users\asus\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# c:\users\asus\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# c:\users\asus\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'floorInt'

# %%
df1['floorInt'].head()
# Out:
# 0    1
# 2    1
# 3    1
# 4    1
# 6    2
# Name: floorInt, dtype: int32

# %%
sns.barplot(x='floorInt',y='price',hue='yr_reno', data =df1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-df81f4ab0c0d> in <module>
# ----> 1 sns.barplot(x='floorInt',y='price',hue='yr_reno', data =df1)
#
# c:\users\asus\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# c:\users\asus\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# c:\users\asus\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'yr_reno'

# %%
sns.barplot(x='floorInt',y='price',hue='yr_reno', data =df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-2529e0ede395> in <module>
# ----> 1 sns.barplot(x='floorInt',y='price',hue='yr_reno', data =df)
#
# c:\users\asus\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# c:\users\asus\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# c:\users\asus\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'floorInt'

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'yr_reno'],
#       dtype='object')

# %%
df.shape
df1.shape
# Out:
# (18702, 21)

# %%
df.shape
# Out:
# (21613, 22)

# %%
df1.columns
# Out:
# Index(['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'floorInt'],
#       dtype='object')

# %%
df['floorInt'] = df['floors'].astype(int)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'yr_reno', 'floorInt'],
#       dtype='object')

# %%
df.shape
# Out:
# (21613, 23)

# %%
sns.barplot(x='floorInt',y='price',hue='waterfront', data =df)

# %%
sns.barplot(x='floorInt',y='price', data =df)

# %% [markdown]
# # Renovated houses have much more price than nono-renovated houses

# %%
sns.set(style="darkgrid")
sns.lineplot(x='floorInt',y='sqft_living',data=df1)

# %% [markdown]
# # Houses with 2 floors have more sqft area then houses with 3 floors

# %%
data = df1[['price','bedrooms','bathrooms', 'sqft_living']]
sns.pairplot(data)

# %%
sns.relplot(x = 'sqft_living', y = 'price' , data=df1,legend="full"
# Out:
#   File "<ipython-input-39-140b87d2a0bc>", line 1
#     sns.relplot(x = 'sqft_living', y = 'price' , data=df1,legend="full"
#                                                                        ^
# SyntaxError: unexpected EOF while parsing

# %%
sns.relplot(x = 'sqft_living', y = 'price' , data=df1,legend="full")

# %%
with sns.axes_style('white'):
    sns.jointplot(x = df1['sqft_living'] , y = df1['price'],kind = 'hex', color = 'k')

# %%
sns.jointplot(x = 'sqft_living', y = 'price', data = df1, kind='kde')

# %%
sns.set(style="darkgrid")
sns.lineplot(x='bathrooms',y='price',data=df1)

# %%
sns.boxplot(x = 'bedrooms', y = 'price', data= df1)

# %% [markdown]
# # Houses with 5 rooms and 6 rooms have almost same price

# %%
sns.barplot(x='grade',y='price', data =df1)

# %% [markdown]
# # MORE THE grade more the price

# %% [markdown]
# # Coorelation and Head Map¶

# %%
cor_mat = df1.corr()

sns.heatmap(cor_mat)

# %% [markdown]
# # Conclusion
#  - Houses with 1 floor are more then houses with 3 floors
#  - Max number of houses are built between 2000-2020
#  - Majority of the people live in around 300 sqft - 6000 sqft of houses
#  - Houses with 2 floors have more sqft area then houses with 3 floors
#  - More the grade of house more the price
