# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('weather_3.csv')

# %%
df=pd.DataFrame(data)
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0          NW           30.0         SW  ...          29       1019.7
# 1         ENE           39.0          E  ...          36       1012.4
# 2          NW           85.0          N  ...          69       1009.5
# 3          NW           54.0        WNW  ...          56       1005.5
# 4         SSE           50.0        SSE  ...          49       1018.3
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %%
x1=df['MaxTemp']
x2=df['Rainfall']
plt.plot(x, y)
plt.title("maxtemp vs rainfall")
plt.xlabel("maxtemp")
plt.ylabel("rainfall")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-42ae61a2ff17> in <module>
#       1 x1=df['MaxTemp']
#       2 x2=df['Rainfall']
# ----> 3 plt.plot(x, y)
#       4 plt.title("maxtemp vs rainfall")
#       5 plt.xlabel("maxtemp")
#
# NameError: name 'x' is not defined

# %%
x1=df['MaxTemp']
x2=df['Rainfall']
plt.plot(x1, x2)
plt.title("maxtemp vs rainfall")
plt.xlabel("maxtemp")
plt.ylabel("rainfall")
plt.show()

# %%
x=df["MaxTemp"]
sns.distplot(x)

# %%
x=df["Evaporation"]
sns.kdeplot(x, shade=True)

# %%
sns.jointplot(x='Evaporation', y='Sunshine',data = df)

# %%
with sns.axes_style('white'):
    sns.jointplot(x = df['Pressure9am'], y = df['Temp9am'], kind = 'hex', color = 'k')

# %%
sns.jointplot(x='Cloud9am', y='Humidity9am', data=df, kind='hist')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-06d3d9de8eee> in <module>
# ----> 1 sns.jointplot(x='Cloud9am', y='Humidity9am', data=df, kind='hist')
#
# c:\users\asus\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2344     else:
#    2345         msg = "kind must be either 'scatter', 'reg', 'resid', 'kde', or 'hex'"
# -> 2346         raise ValueError(msg)
#    2347
#    2348     if stat_func is not None:
#
# ValueError: kind must be either 'scatter', 'reg', 'resid', 'kde', or 'hex'

# %%
sns.jointplot(x='Cloud9am', y='Humidity9am', data=df, kind='reg')

# %%
plt.scatter(x=df["WindGustSpeed"], y=df["Sunshine"])

# %%
sns.stripplot(x ='Cloud3pm' , y='Humidity3pm', data=df)

# %%
sns.swarmplot(x ='Cloud3pm' , y='Humidity3pm', data=df)

# %%
sns.boxplot(x ='Cloud9am' , y='Humidity9am', data=df)

# %%
sns.barplot(x='RainToday', y='Cloud9am', data=df)

# %%
sns.barplot(x='Cloud3pm', y='Humidity3pm', data=df, hue='RainToday')
